# %%
#install openCv
# !pip install opencv-contrib-python==4.1.2.30 --user
# Out:
# Requirement already satisfied: opencv-contrib-python==4.1.2.30 in /usr/local/lib/python3.6/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-contrib-python==4.1.2.30) (1.18.5)

# %%
#import all required libraries
import cv2 
import glob
import pandas as pd
import numpy as np
import pywt
import re
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # (1) run this code to enable the function to get color attributes

# %%
def brightness(opened_file):
  Bright = cv2.cvtColor(opened_file, cv2.COLOR_BGR2GRAY)

  return round(Bright.mean(), 2)

def saturation(opened_file):
  hsv = cv2.cvtColor(opened_file, cv2.COLOR_BGR2HSV)

  # saturation is the s channel
  s = hsv[:, :, 1]

  return round(s.mean(), 2)

def contrast_of_brightness(opened_file):
  gray = cv2.cvtColor(opened_file, cv2.COLOR_BGR2GRAY)

  return round(gray.std(), 2)


def image_clarity(opened_file):
  gray = cv2.cvtColor(opened_file, cv2.COLOR_BGR2GRAY) 
  bright = gray >= .7

  return round(bright.sum() / bright.size, 2)
  
def warm_hue(opened_file):
  hsv = cv2.cvtColor(opened_file, cv2.COLOR_BGR2HSV)

  # hue is the h channel
  h = hsv[:, :, 0]
  warm = ~ (h > 30) & (h < 210)

  return round(warm.sum() / warm.size, 2)

def image_colorfulness(opened_file):
  # split the image into its respective RGB components
  (B, G, R) = cv2.split(opened_file.astype("float"))

  # compute rg = R - G
  rg = np.absolute(R - G)

  # compute yb = 0.5 * (R + G) - B
  yb = np.absolute(0.5 * (R + G) - B)

  # compute the mean and standard deviation of both `rg` and `yb`
  (rbMean, rbStd) = (np.mean(rg), np.std(rg))
  (ybMean, ybStd) = (np.mean(yb), np.std(yb))

  # combine the mean and standard deviations
  std_root = np.sqrt((rbStd ** 2) + (ybStd ** 2))
  mean_root = np.sqrt((rbMean ** 2) + (ybMean ** 2))

  # derive the "colorfulness" metric and return it
  return round(std_root + (0.3 * mean_root))

# %% [markdown]
# (2) composition

# %%
def Composition_variables (image):
    # this function returns the vaules corresponding to
    # 1- Rule of third
    # 2- Diagonal dominance 
    # 3- Vertical physical visual balance
    # 4- Horizontal physical visual balance
    
    
    #__________________________________________________________
    # Rule of third
    saliency = cv2.saliency.StaticSaliencyFineGrained_create()
    (success, saliencyMap) = saliency.computeSaliency(image)
    new_arr = ((saliencyMap - saliencyMap.min()) * (1/(saliencyMap.max() - saliencyMap.min()) * 255))
    threshMap = cv2.threshold(new_arr.astype('uint8'), 0, 255, cv2.THRESH_OTSU)[1]
    contours, hierarchy = cv2.findContours(threshMap,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    img_copy = image.copy()
    fx = 0
    fy = 0
    for c in contours:
       # calculate moments for each contour
        M = cv2.moments(c)
        area = cv2.contourArea(c)
        #img_copy = cv2.drawContours(img_copy, contours, contourIdx = -1, 
        #                     color = (255, 0, 0), thickness = 2)
        #print(area)
       # calculate x,y coordinate of center

        if M["m00"]!= 0.0:

            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            fx= fx + cX
            fy = fy + cY

    fx = round(fx/len(contours))
    fy = round(fy/len(contours)) 
    #cv2.circle(image, (fx, fy), 5, (255, 255, 255), -1)
    #cv2.putText(image, "centroid", (fx - 25, fy - 25),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
    y,x,c = image.shape
    P = [[y/3, x/3],[y/3, 2*x/3],[2*y/3, x/3],[2*y/3, 2*x/3]]
    dist =[]
    for p in P:
        d = ((fy-p[0])**2+(fx-p[1])**2)**.5
        dist.append(d)
    
    #__________________________________________________________
    # Diagonal dominance 
    xc = fx
    yc = fy

    ycc = y-yc
    yccp = xc*y/x
    theta = np.arctan(y/x)
    d1 = abs((ycc-yccp)*np.cos(theta))
    ycc,yccp,theta,d1

    xcp = x - (x/y*ycc)
    d2 = abs((xc-xcp)*np.sin(theta))
    
    #__________________________________________________________
    #  physical visual balance 
    
    ver_balance = -abs(y/2-fy)
    hor_balance = -abs(x/2-fx)

    return (min(dist), min(d1,d2),-ver_balance,-hor_balance)
  
def horizontal_color_balance(opened_file):
  mid = int(opened_file.shape[1] / 2)
  left_half = np.array(opened_file[:, 0:mid, ], dtype='int')
  right_half = np.flip(np.array(opened_file[:, mid:2 * mid, ],
                                      dtype='int'), axis=1)
  dif_square = np.square(left_half - right_half)
  euclidean = np.sqrt(dif_square.sum(axis=2))

  return round(euclidean.mean(), 2)

def vertical_color_balance(opened_file):
  mid = int(opened_file.shape[0] / 2)
  upper_half = np.array(opened_file[0:mid,: , ], dtype='int')
  lower_half = np.flip(np.array(opened_file[mid:2 * mid,: , ],
                                      dtype='int'), axis=1)
  dif_square = np.square(upper_half - lower_half)
  euclidean = np.sqrt(dif_square.sum(axis=2))

  return round(euclidean.mean(), 2)

# %% [markdown]
# (3) figure-background relationshp

# %%
def Difference(opened_file):
    
    #resize image to reduce processing time 
    opened_file = cv2.resize(opened_file, (0, 0), fx=0.5, fy=0.5)
    
    # initialize OpenCV's static fine grained saliency detector and
    # compute the saliency map

    #image = cv2.imread('C:\\Users\\oalq0001\\Downloads\\saliency-detection\\images\\players.jpg')
    saliency = cv2.saliency.StaticSaliencyFineGrained_create()
    (success, saliencyMap) = saliency.computeSaliency(opened_file)
    # change the scale into 0-255
    new_arr = ((saliencyMap - saliencyMap.min()) * (1/(saliencyMap.max() - saliencyMap.min()) * 255))

  
    threshMap = cv2.threshold(new_arr.astype('uint8'), 0, 255, cv2.THRESH_OTSU)[1]

    #display objects
    #cv2.imshow("Image", threshMap)
    #cv2.waitKey(0)
    
    kernel1 = np.ones((40,40),np.uint8)
    kernel2 = np.ones((20,20),np.uint8)

    closing = cv2.morphologyEx(threshMap, cv2.MORPH_CLOSE, kernel1)
    threshMap = cv2.erode(closing,kernel2,iterations = 1)

    # calculate Area difference
    objects_size = np.sum(threshMap/255)
    background_size = (threshMap.shape[0]*threshMap.shape[1]) - objects_size
    overall_size = threshMap.shape[0]*threshMap.shape[1]
    
    Area_difference = (objects_size )/(threshMap.shape[0]*threshMap.shape[1])
    
    # calculate Color
    Objects_image = cv2.bitwise_and(opened_file,opened_file,mask = (threshMap/255).astype('uint8'))
    Background_image = cv2.bitwise_and(opened_file,opened_file,mask = ~(threshMap).astype('uint8'))
    
    R_Obj = np.sum(Objects_image[:,:,0])/objects_size
    G_Obj = np.sum(Objects_image[:,:,1])/objects_size
    B_Obj = np.sum(Objects_image[:,:,2])/objects_size
    
    R_back = np.sum(Background_image[:,:,0])/background_size
    G_back = np.sum(Background_image[:,:,1])/background_size
    B_back = np.sum(Background_image[:,:,2])/background_size
    
    color_object = str(R_Obj)+','+str(G_Obj)+','+str(B_Obj)
    color_Background = str(R_back)+','+str(G_back)+','+str(B_back)
    
    # calculate Color difference
    
    Color_difference = ((R_Obj - R_back)**2 + (G_Obj - G_back)**2 + (B_Obj - B_back)**2)**.5
    
    #calculate Texture difference
    edges_objects = cv2.Canny(Objects_image, 50, 150, apertureSize=3)
    edges_background = cv2.Canny(Background_image, 50, 150, apertureSize=3)

    edges_objects_density = np.sum(edges_objects/255)/objects_size
    edges_background_density = np.sum(edges_background/255)/background_size

    Texture_difference = abs(edges_background_density - edges_objects_density)
      
    
    return (Texture_difference,Area_difference, Color_difference)
  
def calc_wavelet (block):
    hsv = cv2.cvtColor(block, cv2.COLOR_BGR2HSV)
    sums =[]
    for i in range(3):
        Channel = hsv[:,:,i]
        coffes_H=pywt.dwt2(Channel,'db1')
        ca,(ch,cv,cd)= coffes_H
        sums.append (np.sum(cd))
    return sums


def Depth_of_field (image):
    
    # Define the window size
    windowsize_r = round(image.shape[0]/4)
    windowsize_c = round(image.shape[1]/4)

    # devide the image into blocks
    window = np.zeros(shape=(windowsize_r,windowsize_c,3,16)).astype('uint8')
    k = 0
    for r in range(0,image.shape[0] - windowsize_r, windowsize_r):
        for c in range(0,image.shape[1] - windowsize_c, windowsize_c):
            window[:,:,:,k] = image[r:r+windowsize_r,c:c+windowsize_c]
            k = k +1
            #display objects

    #center blocks
    center = [5,6,9,10]

    #calaculate the wavelet coeff. for center blocks
    sum_center_blocks = np.zeros(shape = [3])
    for i in center:
        block = window[:,:,:,i]
        Sums = calc_wavelet (block)
        sum_center_blocks = sum_center_blocks + Sums

    #calaculate the wavelet coeff. for whole image 
    Sum_whole_image = calc_wavelet (image)

    #return  the depth of feild for each channel (H,S, and V)
    return abs(sum_center_blocks/Sum_whole_image)

# %%
import glob

# %%
# make sure to put the right path. 

list_of_files_loc = glob.glob('/content/drive/My Drive/Instagram_Images.jpg/*.*')
list_of_files = [x for x in list_of_files_loc if re.search('jpg',x)]#if your pictures are not .jpg, then please change ".jpg" to other type

# %%
len(list_of_files_loc)
# Out:
# 1261

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#check if you get all the pictures
len(list_of_files) #if you have 1000 pictures, then the length of this list of files should be 1000
# Out:
# 1261

# %%
#this is the function to extract all 18 features from one picture
def collect_features (filename):
    image = cv2.imread(filename)
    id = filename.split("/")[-1].split('.')[0]
    (Depth_of_field_hue, Depth_of_field_saturation, Depth_of_field_saturation_value) = Depth_of_field (image)
    Brightness = brightness (image)
    Saturation = saturation (image)
    Contrast = contrast_of_brightness (image)
    Clarity = image_clarity (image)
    Warm_hue = warm_hue (image)
    Colorfulness = image_colorfulness (image)
    hor_color = horizontal_color_balance(image)
    ver_color = vertical_color_balance(image)
    (Rule_third, diagonal_dom, physical_ver, physical_hor) = Composition_variables(image)
    (Texture_difference,Area_difference, Color_difference) = Difference(image)
    

    #we extract all the visual features from one picture 
    visual_features  ={'short_code':id,
               'Colorfulness_Picture':Colorfulness,
               'Saturation_Picture': Saturation, 
               'Contrast_Picture':Contrast,
               'Clarity_Picture':Clarity,
               'Brightness_Picture':Brightness,
               'Warm Hue_Picture':Warm_hue,
               
               'ROT_Picture':Rule_third,
               'Diagonal_dominance_Picture':diagonal_dom,
               'Physical_ver_Picture':physical_ver,
               'Physical_Hor_Picture':physical_hor,
               'Color_balance_vertical_Picture':ver_color,
               'Color_balance_horizontal_Picture':hor_color,
               
               
               'Texture_difference_Picture':Texture_difference,
               'Size_difference_Picture':Area_difference,
               'Color_difference_Picture':Color_difference,
               'Depth of field_hue_Picture':Depth_of_field_hue,
               'Depth of field_saturation_Picture':Depth_of_field_saturation,
               'Depth of field_value_Picture':Depth_of_field_saturation_value,
               
              }
    
    
    return visual_features

# %%
all_features_combined = []
#loop over list_of_files
for i,filename in enumerate (list_of_files):
    print('processing image no.:',i)
    # send the image name to collect_features function append then results to list
    try:
      all_features = collect_features (filename)
      all_features_combined.append(all_features)
    except:
      continue
# Out:
# processing image no.: 0
# processing image no.: 1
# processing image no.: 2
# processing image no.: 3
# processing image no.: 4
# processing image no.: 5
# processing image no.: 6
# processing image no.: 7
# processing image no.: 8
# processing image no.: 9
# processing image no.: 10
# processing image no.: 11
# processing image no.: 12
# processing image no.: 13
# processing image no.: 14
# processing image no.: 15
# processing image no.: 16
# processing image no.: 17
# processing image no.: 18
# processing image no.: 19
# processing image no.: 20
# processing image no.: 21
# processing image no.: 22
# processing image no.: 23
# processing image no.: 24
# processing image no.: 25
# processing image no.: 26
# processing image no.: 27
# processing image no.: 28
# processing image no.: 29
# processing image no.: 30
# processing image no.: 31
# processing image no.: 32
# processing image no.: 33
# processing image no.: 34
# processing image no.: 35
# processing image no.: 36
# processing image no.: 37
# processing image no.: 38
# processing image no.: 39
# processing image no.: 40
# processing image no.: 41
# processing image no.: 42
# processing image no.: 43
# processing image no.: 44
# processing image no.: 45
# processing image no.: 46
# processing image no.: 47
# processing image no.: 48
# processing image no.: 49
# processing image no.: 50
# processing image no.: 51
# processing image no.: 52
# processing image no.: 53
# processing image no.: 54
# processing image no.: 55
# processing image no.: 56
# processing image no.: 57
# processing image no.: 58
# processing image no.: 59
# processing image no.: 60
# processing image no.: 61
# processing image no.: 62
# processing image no.: 63
# processing image no.: 64
# processing image no.: 65
# processing image no.: 66
# processing image no.: 67
# processing image no.: 68
# processing image no.: 69
# processing image no.: 70
# processing image no.: 71
# processing image no.: 72
# processing image no.: 73
# processing image no.: 74
# processing image no.: 75
# processing image no.: 76
# processing image no.: 77
# processing image no.: 78
# processing image no.: 79
# processing image no.: 80
# processing image no.: 81
# processing image no.: 82
# processing image no.: 83
# processing image no.: 84
# processing image no.: 85
# processing image no.: 86
# processing image no.: 87
# processing image no.: 88
# processing image no.: 89
# processing image no.: 90
# processing image no.: 91
# processing image no.: 92
# processing image no.: 93
# processing image no.: 94
# processing image no.: 95
# processing image no.: 96
# processing image no.: 97
# processing image no.: 98
# processing image no.: 99
# processing image no.: 100
# processing image no.: 101
# processing image no.: 102
# processing image no.: 103
# processing image no.: 104
# processing image no.: 105
# processing image no.: 106
# processing image no.: 107
# processing image no.: 108
# processing image no.: 109
# processing image no.: 110
# processing image no.: 111
# processing image no.: 112
# processing image no.: 113
# processing image no.: 114
# processing image no.: 115
# processing image no.: 116
# processing image no.: 117
# processing image no.: 118
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:43: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:59
# processing image no.: 1037
# processing image no.: 1038
# processing image no.: 1039
# processing image no.: 1040
# processing image no.: 1041
# processing image no.: 1042
# processing image no.: 1043
# processing image no.: 1044
# processing image no.: 1045
# processing image no.: 1046
# processing image no.: 1047
# processing image no.: 1048
# processing image no.: 1049
# processing image no.: 1050
# processing image no.: 1051
# processing image no.: 1052
# processing image no.: 1053
# processing image no.: 1054
# processing image no.: 1055
# processing image no.: 1056
# processing image no.: 1057
# processing image no.: 1058
# processing image no.: 1059
# processing image no.: 1060
# processing image no.: 1061
# processing image no.: 1062
# processing image no.: 1063
# processing image no.: 1064
# processing image no.: 1065
# processing image no.: 1066
# processing image no.: 1067
# processing image no.: 1068
# processing image no.: 1069
# processing image no.: 1070
# processing image no.: 1071
# processing image no.: 1072
# processing image no.: 1073
# processing image no.: 1074
# processing image no.: 1075
# processing image no.: 1076
# processing image no.: 1077
# processing image no.: 1078
# processing image no.: 1079
# processing image no.: 1080
# processing image no.: 1081
# processing image no.: 1082
# processing image no.: 1083
# processing image no.: 1084
# processing image no.: 1085
# processing image no.: 1086
# processing image no.: 1087
# processing image no.: 1088
# processing image no.: 1089
# processing image no.: 1090
# processing image no.: 1091
# processing image no.: 1092
# processing image no.: 1093
# processing image no.: 1094
# processing image no.: 1095
# processing image no.: 1096
# processing image no.: 1097
# processing image no.: 1098
# processing image no.: 1099
# processing image no.: 1100
# processing image no.: 1101
# processing image no.: 1102
# processing image no.: 1103
# processing image no.: 1104
# processing image no.: 1105
# processing image no.: 1106
# processing image no.: 1107
# processing image no.: 1108
# processing image no.: 1109
# processing image no.: 1110
# processing image no.: 1111
# processing image no.: 1112
# processing image no.: 1113
# processing image no.: 1114
# processing image no.: 1115
# processing image no.: 1116
# processing image no.: 1117
# processing image no.: 1118
# processing image no.: 1119
# processing image no.: 1120
# processing image no.: 1121
# processing image no.: 1122
# processing image no.: 1123
# processing image no.: 1124
# processing image no.: 1125
# processing image no.: 1126
# processing image no.: 1127
# processing image no.: 1128
# processing image no.: 1129
# processing image no.: 1130
# processing image no.: 1131
# processing image no.: 1132
# processing image no.: 1133
# processing image no.: 1134
# processing image no.: 1135
# processing image no.: 1136
# processing image no.: 1137
# processing image no.: 1138
# processing image no.: 1139
# processing image no.: 1140
# processing image no.: 1141
# processing image no.: 1142
# processing image no.: 1143
# processing image no.: 1144
# processing image no.: 1145
# processing image no.: 1146
# processing image no.: 1147
# processing image no.: 1148
# processing image no.: 1149
# processing image no.: 1150
# processing image no.: 1151
# processing image no.: 1152
# processing image no.: 1153
# processing image no.: 1154
# processing image no.: 1155
# processing image no.: 1156
# processing image no.: 1157
# processing image no.: 1158
# processing image no.: 1159
# processing image no.: 1160
# processing image no.: 1161
# processing image no.: 1162
# processing image no.: 1163
# processing image no.: 1164
# processing image no.: 1165
# processing image no.: 1166
# processing image no.: 1167
# processing image no.: 1168
# processing image no.: 1169
# processing image no.: 1170
# processing image no.: 1171
# processing image no.: 1172
# processing image no.: 1173
# processing image no.: 1174
# processing image no.: 1175
# processing image no.: 1176
# processing image no.: 1177
# processing image no.: 1178
# processing image no.: 1179
# processing image no.: 1180
# processing image no.: 1181
# processing image no.: 1182
# processing image no.: 1183
# processing image no.: 1184
# processing image no.: 1185
# processing image no.: 1186
# processing image no.: 1187
# processing image no.: 1188
# processing image no.: 1189
# processing image no.: 1190
# processing image no.: 1191
# processing image no.: 1192
# processing image no.: 1193
# processing image no.: 1194
# processing image no.: 1195
# processing image no.: 1196
# processing image no.: 1197
# processing image no.: 1198
# processing image no.: 1199
# processing image no.: 1200
# processing image no.: 1201
# processing image no.: 1202
# processing image no.: 1203
# processing image no.: 1204
# processing image no.: 1205
# processing image no.: 1206
# processing image no.: 1207
# processing image no.: 1208
# processing image no.: 1209
# processing image no.: 1210
# processing image no.: 1211
# processing image no.: 1212
# processing image no.: 1213
# processing image no.: 1214
# processing image no.: 1215
# processing image no.: 1216
# processing image no.: 1217
# processing image no.: 1218
# processing image no.: 1219
# processing image no.: 1220
# processing image no.: 1221
# processing image no.: 1222
# processing image no.: 1223
# processing image no.: 1224
# processing image no.: 1225
# processing image no.: 1226
# processing image no.: 1227
# processing image no.: 1228
# processing image no.: 1229
# processing image no.: 1230
# processing image no.: 1231
# processing image no.: 1232
# processing image no.: 1233
# processing image no.: 1234
# processing image no.: 1235
# processing image no.: 1236
# processing image no.: 1237
# processing image no.: 1238
# processing image no.: 1239
# processing image no.: 1240
# processing image no.: 1241
# processing image no.: 1242
# processing image no.: 1243
# processing image no.: 1244
# processing image no.: 1245
# processing image no.: 1246
# processing image no.: 1247
# processing image no.: 1248
# processing image no.: 1249
# processing image no.: 1250
# processing image no.: 1251
# processing image no.: 1252
# processing image no.: 1253
# processing image no.: 1254
# processing image no.: 1255
# processing image no.: 1256
# processing image no.: 1257
# processing image no.: 1258
# processing image no.: 1259
# processing image no.: 1260

# %%
#check your visual features
all_features_combined[:5]
# Out:
# [{'Brightness_Picture': 60.65,
#   'Clarity_Picture': 1.0,
#   'Color_balance_horizontal_Picture': 57.83,
#   'Color_balance_vertical_Picture': 88.24,
#   'Color_difference_Picture': 73.27166101254501,
#   'Colorfulness_Picture': 34.0,
#   'Contrast_Picture': 45.96,
#   'Depth of field_hue_Picture': 3.4948453608247325,
#   'Depth of field_saturation_Picture': 0.6453215567209489,
#   'Depth of field_value_Picture': 0.21364985163205186,
#   'Diagonal_dominance_Picture': 28.2842712474619,
#   'Physical_Hor_Picture': 46.0,
#   'Physical_ver_Picture': 86.0,
#   'ROT_Picture': 58.240879114244144,
#   'Saturation_Picture': 136.43,
#   'Size_difference_Picture': 0.391996667948225,
#   'Texture_difference_Picture': 0.0693572859874101,
#   'Warm Hue_Picture': 0.95,
#   'short_code': '342'},
#  {'Brightness_Picture': 76.72,
#   'Clarity_Picture': 1.0,
#   'Color_balance_horizontal_Picture': 99.52,
#   'Color_balance_vertical_Picture': 95.74,
#   'Color_difference_Picture': 77.82612691667529,
#   'Colorfulness_Picture': 42.0,
#   'Contrast_Picture': 52.41,
#   'Depth of field_hue_Picture': 0.10845447589900532,
#   'Depth of field_saturation_Picture': 0.01532567049808408,
#   'Depth of field_value_Picture': 0.37837837837837973,
#   'Diagonal_dominance_Picture': 2.9503629846802415,
#   'Physical_Hor_Picture': 93.0,
#   'Physical_ver_Picture': 68.0,
#   'ROT_Picture': 103.82731389721641,
#   'Saturation_Picture': 169.02,
#   'Size_difference_Picture': 0.28010497128144185,
#   'Texture_difference_Picture': 0.10610175993633236,
#   'Warm Hue_Picture': 0.93,
#   'short_code': '343'},
#  {'Brightness_Picture': 57.69,
#   'Clarity_Picture': 1.0,
#   'Color_balance_horizontal_Picture': 71.45,
#   'Color_balance_vertical_Picture': 104.16,
#   'Color_difference_Picture': 118.80570612942367,
#   'Colorfulness_Picture': 25.0,
#   'Contrast_Picture': 53.58,
#   'Depth of field_hue_Picture': 1.7174476100777027,
#   'Depth of field_saturation_Picture': 0.39187996469549524,
#   'Depth of field_value_Picture': 0.1618257261410778,
#   'Diagonal_dominance_Picture': 88.75203139603664,
#   'Physical_Hor_Picture': 89.0,
#   'Physical_ver_Picture': 166.0,
#   'ROT_Picture': 101.96568050084302,
#   'Saturation_Picture': 101.3,
#   'Size_difference_Picture': 0.2672582304526749,
#   'Texture_difference_Picture': 0.16082060607811866,
#   'Warm Hue_Picture': 0.11,
#   'short_code': '346'},
#  {'Brightness_Picture': 98.85,
#   'Clarity_Picture': 1.0,
#   'Color_balance_horizontal_Picture': 83.18,
#   'Color_balance_vertical_Picture': 116.01,
#   'Color_difference_Picture': 39.55264453372074,
#   'Colorfulness_Picture': 57.0,
#   'Contrast_Picture': 59.06,
#   'Depth of field_hue_Picture': 0.03644008409250177,
#   'Depth of field_saturation_Picture': 0.09943001899936284,
#   'Depth of field_value_Picture': 0.27647058823530135,
#   'Diagonal_dominance_Picture': 11.31370849898476,
#   'Physical_Hor_Picture': 53.0,
#   'Physical_ver_Picture': 37.0,
#   'ROT_Picture': 191.25375813301028,
#   'Saturation_Picture': 176.07,
#   'Size_difference_Picture': 0.30276063100137174,
#   'Texture_difference_Picture': 0.10204026526172269,
#   'Warm Hue_Picture': 0.93,
#   'short_code': '348'},
#  {'Brightness_Picture': 132.42,
#   'Clarity_Picture': 1.0,
#   'Color_balance_horizontal_Picture': 138.5,
#   'Color_balance_vertical_Picture': 135.02,
#   'Color_difference_Picture': 43.58982022433892,
#   'Colorfulness_Picture': 51.0,
#   'Contrast_Picture': 66.88,
#   'Depth of field_hue_Picture': 0.643780290791599,
#   'Depth of field_saturation_Picture': 0.0563494829789703,
#   'Depth of field_value_Picture': 1.0476190476190352,
#   'Diagonal_dominance_Picture': 3.5355339059327373,
#   'Physical_Hor_Picture': 15.0,
#   'Physical_ver_Picture': 20.0,
#   'ROT_Picture': 229.83689869122406,
#   'Saturation_Picture': 84.33,
#   'Size_difference_Picture': 0.42979080932784636,
#   'Texture_difference_Picture': 0.09468865763341912,
#   'Warm Hue_Picture': 0.35,
#   'short_code': '350'}]

# %%
import pandas as pd

# %%
# save the results in a DataFrame
visual_data = pd.DataFrame(all_features_combined).astype(np.float64)

# %%
#check our visual data
visual_data.head()
# Out:
#    short_code  ...  Depth of field_value_Picture
# 0       342.0  ...                      0.213650
# 1       343.0  ...                      0.378378
# 2       346.0  ...                      0.161826
# 3       348.0  ...                      0.276471
# 4       350.0  ...                      1.047619
#
# [5 rows x 19 columns]

# %%
#then, you can download your visual_data dataframe. use this code to download the the dataframe. 
from google.colab import files

visual_data.to_csv("visual_features_fromOpenCV.csv", index=False)
files.download('visual_features_fromOpenCV.csv')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-505e292e-87a2-4043-b0c5-b2293d37fd50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-505e292e-87a2-4043-b0c5-b2293d37fd50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Nespresso (1).xlsx to Nespresso (1).xlsx

# %%
#import the pictures data with likes
likes_data = pd.read_excel("Nespresso (1).xlsx").loc[:,["short_code","likeCount"]]

# %%
#check your data
likes_data.head()
# Out:
#    short_code  likeCount
# 0         342      667.0
# 1         343     3297.0
# 2         346     4483.0
# 3         348     4187.0
# 4         350     4935.0

# %%
#merge the data
data_ready = visual_data.merge(likes_data, on="short_code", how="inner").fillna(0)

# %%
#start the regression
y = data_ready['likeCount']#your Y / dependent variable
x = data_ready.drop(['likeCount'], axis=1).astype(float) #your X/ Independent variabels
x = sm.add_constant(x)
model= sm.OLS(y, x).fit()

# %%
#start the regression
y = data_ready['eng_score']#your Y / dependent variable
x = data_ready.drop(['eng_score'], axis=1).astype(float) #your X/ Independent variabels
x = sm.add_constant(x)
model2= sm.OLS(y, x).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              eng_score   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     6.403
# Date:                Fri, 14 Aug 2020   Prob (F-statistic):           4.30e-16
# Time:                        05:04:33   Log-Likelihood:                 953.35
# No. Observations:                1261   AIC:                            -1867.
# Df Residuals:                    1241   BIC:                            -1764.
# Df Model:                          19
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                -0.0899      0.071     -1.260      0.208      -0.230       0.050
# short_code                         7.334e-05   8.06e-06      9.098      0.000    5.75e-05    8.92e-05
# Colorfulness_Picture                  0.0005      0.000      1.898      0.058   -1.74e-05       0.001
# Saturation_Picture                   -0.0002      0.000     -1.647      0.100      -0.001    4.56e-05
# Contrast_Picture                     -0.0006      0.000     -1.187      0.235      -0.002       0.000
# Clarity_Picture                       0.1205      0.068      1.771      0.077      -0.013       0.254
# Brightness_Picture                   -0.0001      0.000     -1.058      0.290      -0.000       0.000
# Warm Hue_Picture                     -0.0030      0.013     -0.231      0.817      -0.029       0.023
# ROT_Picture                           0.0003   8.33e-05      3.156      0.002    9.94e-05       0.000
# Diagonal_dominance_Picture           -0.0002      0.000     -1.666      0.096      -0.000    3.74e-05
# Physical_ver_Picture                  0.0002   6.76e-05      3.514      0.000       0.000       0.000
# Physical_Hor_Picture                  0.0002   7.19e-05      3.101      0.002    8.19e-05       0.000
# Color_balance_vertical_Picture    -4.509e-05      0.000     -0.269      0.788      -0.000       0.000
# Color_balance_horizontal_Picture      0.0002      0.000      1.845      0.065   -1.54e-05       0.000
# Texture_difference_Picture            0.1247      0.076      1.636      0.102      -0.025       0.274
# Size_difference_Picture              -0.0247      0.019     -1.327      0.185      -0.061       0.012
# Color_difference_Picture           2.277e-05   8.25e-05      0.276      0.783      -0.000       0.000
# Depth of field_hue_Picture           -0.0001      0.000     -0.593      0.553      -0.000       0.000
# Depth of field_saturation_Picture -8.386e-05      0.000     -0.456      0.648      -0.000       0.000
# Depth of field_value_Picture         -0.0003      0.000     -0.762      0.446      -0.001       0.000
# ==============================================================================
# Omnibus:                      548.540   Durbin-Watson:                   1.164
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3258.012
# Skew:                           1.938   Prob(JB):                         0.00
# Kurtosis:                       9.855   Cond. No.                     2.97e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              likeCount   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     10.83
# Date:                Fri, 14 Aug 2020   Prob (F-statistic):           1.51e-30
# Time:                        04:40:42   Log-Likelihood:                -11884.
# No. Observations:                1261   AIC:                         2.381e+04
# Df Residuals:                    1241   BIC:                         2.391e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                             -3133.0100   1880.924     -1.666      0.096   -6823.152     557.132
# short_code                            2.5815      0.213     12.139      0.000       2.164       2.999
# Colorfulness_Picture                 17.3791      7.156      2.429      0.015       3.340      31.418
# Saturation_Picture                   -7.1022      3.818     -1.860      0.063     -14.593       0.388
# Contrast_Picture                    -20.6480     12.796     -1.614      0.107     -45.751       4.455
# Clarity_Picture                    3831.2924   1795.509      2.134      0.033     308.723    7353.862
# Brightness_Picture                   -3.7355      2.959     -1.262      0.207      -9.541       2.070
# Warm Hue_Picture                    -35.5868    343.785     -0.104      0.918    -710.051     638.878
# ROT_Picture                           8.5176      2.197      3.878      0.000       4.208      12.827
# Diagonal_dominance_Picture           -7.9382      3.341     -2.376      0.018     -14.493      -1.383
# Physical_ver_Picture                  7.0478      1.782      3.954      0.000       3.551      10.545
# Physical_Hor_Picture                  5.4021      1.896      2.849      0.004       1.682       9.122
# Color_balance_vertical_Picture       -0.0962      4.429     -0.022      0.983      -8.786       8.594
# Color_balance_horizontal_Picture      8.3141      3.456      2.406      0.016       1.535      15.094
# Texture_difference_Picture         3605.6811   2009.807      1.794      0.073    -337.315    7548.677
# Size_difference_Picture            -788.0551    491.483     -1.603      0.109   -1752.285     176.174
# Color_difference_Picture              1.1483      2.176      0.528      0.598      -3.120       5.417
# Depth of field_hue_Picture           -3.0305      4.724     -0.641      0.521     -12.299       6.238
# Depth of field_saturation_Picture    -2.7632      4.849     -0.570      0.569     -12.277       6.750
# Depth of field_value_Picture         -7.4888      8.924     -0.839      0.402     -24.996      10.019
# ==============================================================================
# Omnibus:                      184.637   Durbin-Watson:                   0.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              322.564
# Skew:                           0.929   Prob(JB):                     9.04e-71
# Kurtosis:                       4.638   Cond. No.                     2.97e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#interpret the regression
df_coeffs = pd.DataFrame({"Coefficients": model.params, "p": model.pvalues})

df_coeffs_sorted = df_coeffs.reindex(df_coeffs["p"].sort_values().index)
df_coeffs_sorted.style.bar(subset = ["Coefficients", "p"], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_31c02c38_dde9_11ea_b808_0242ac1c0002row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, #5fba7d 45.0%, #5fba7d 45.0%, transparent 45.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.0%, transparent 0.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, #5fba7d 45.0%, #5fba7d 45.1%, transparent 45.1%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.0%, transparent 0.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, #5fba7d 45.0%, #5fba7d 45.1%, transparent 45.1%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.0%, transparent 0.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, #5fba7d 45.0%, #5fba7d 45.1%, transparent 45.1%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.5%, transparent 0.5%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, #5fba7d 45.0%, #5fba7d 45.2%, transparent 45.2%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.6%, transparent 1.6%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, #5fba7d 45.0%, #5fba7d 45.1%, transparent 45.1%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.7%, transparent 1.7%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, #d65f5f 44.9%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.8%, transparent 1.8%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, #5fba7d 45.0%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 3.4%, transparent 3.4%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, #d65f5f 44.9%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 6.4%, transparent 6.4%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, #5fba7d 45.0%, #5fba7d 96.8%, transparent 96.8%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 7.4%, transparent 7.4%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 45.0%, transparent 45.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 9.8%, transparent 9.8%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #d65f5f 44.7%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.9%, transparent 10.9%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.7%, #d65f5f 33.7%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.1%, transparent 11.1%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, #d65f5f 44.9%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 21.1%, transparent 21.1%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, #d65f5f 44.9%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 40.9%, transparent 40.9%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, #d65f5f 44.9%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 53.1%, transparent 53.1%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, #d65f5f 44.9%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 57.9%, transparent 57.9%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, #5fba7d 45.0%, #5fba7d 45.0%, transparent 45.0%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 60.8%, transparent 60.8%);
#         }    #T_31c02c38_dde9_11ea_b808_0242ac1c0002row18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.5%, #d65f5f 44.5%, #d65f5f 45.0%, transparent 4

# %%
model.pvalues[model.pvalues<0.05]
# Out:
# short_code                          3.996099e-32
# Colorfulness_Picture                1.529669e-02
# Clarity_Picture                     3.305318e-02
# ROT_Picture                         1.109471e-04
# Diagonal_dominance_Picture          1.766349e-02
# Physical_ver_Picture                8.112892e-05
# Physical_Hor_Picture                4.462117e-03
# Color_balance_horizontal_Picture    1.627492e-02
# dtype: float64

# %%
model.params[model.pvalues<0.05]
# Out:
# short_code                             2.581486
# Colorfulness_Picture                  17.379083
# Clarity_Picture                     3831.292420
# ROT_Picture                            8.517649
# Diagonal_dominance_Picture            -7.938190
# Physical_ver_Picture                   7.047779
# Physical_Hor_Picture                   5.402078
# Color_balance_horizontal_Picture       8.314086
# dtype: float64

# %%
df_coeffs = pd.DataFrame({"Coefficients": model.params[model.pvalues<0.05], "p": model.pvalues[model.pvalues<0.05]})

df_coeffs_sorted = df_coeffs.reindex(df_coeffs["p"].sort_values().index)
df_coeffs_sorted.style.bar(subset = ["Coefficients", "p"], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #5fba7d 0.2%, #5fba7d 0.3%, transparent 0.3%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.0%, transparent 0.0%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #5fba7d 0.2%, #5fba7d 0.4%, transparent 0.4%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.2%, transparent 0.2%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #5fba7d 0.2%, #5fba7d 0.4%, transparent 0.4%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.3%, transparent 0.3%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #5fba7d 0.2%, #5fba7d 0.3%, transparent 0.3%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 13.5%, transparent 13.5%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #5fba7d 0.2%, #5fba7d 0.7%, transparent 0.7%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 46.3%, transparent 46.3%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #5fba7d 0.2%, #5fba7d 0.4%, transparent 0.4%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 49.2%, transparent 49.2%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 53.4%, transparent 53.4%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #5fba7d 0.2%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_f2c40c88_dde9_11ea_b808_0242ac1c0002row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }</style><table id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coefficients</th>        <th class="col_heading level0 col1" >p</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002level0_row0" class="row_heading level0 row0" >short_code</th>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row0_col0" class="data row0 col0" >2.581486</td>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row0_col1" class="data row0 col1" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002level0_row1" class="row_heading level0 row1" >Physical_ver_Picture</th>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row1_col0" class="data row1 col0" >7.047779</td>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row1_col1" class="data row1 col1" >0.000081</td>
#             </tr>
#             <tr>
#                         <th id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002level0_row2" class="row_heading level0 row2" >ROT_Picture</th>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row2_col0" class="data row2 col0" >8.517649</td>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row2_col1" class="data row2 col1" >0.000111</td>
#             </tr>
#             <tr>
#                         <th id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002level0_row3" class="row_heading level0 row3" >Physical_Hor_Picture</th>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row3_col0" class="data row3 col0" >5.402078</td>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row3_col1" class="data row3 col1" >0.004462</td>
#             </tr>
#             <tr>
#                         <th id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002level0_row4" class="row_heading level0 row4" >Colorfulness_Picture</th>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row4_col0" class="data row4 col0" >17.379083</td>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row4_col1" class="data row4 col1" >0.015297</td>
#             </tr>
#             <tr>
#                         <th id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002level0_row5" class="row_heading level0 row5" >Color_balance_horizontal_Picture</th>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row5_col0" class="data row5 col0" >8.314086</td>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row5_col1" class="data row5 col1" >0.016275</td>
#             </tr>
#             <tr>
#                         <th id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002level0_row6" class="row_heading level0 row6" >Diagonal_dominance_Picture</th>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row6_col0" class="data row6 col0" >-7.938190</td>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row6_col1" class="data row6 col1" >0.017663</td>
#             </tr>
#             <tr>
#                         <th id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002level0_row7" class="row_heading level0 row7" >Clarity_Picture</th>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row7_col0" class="data row7 col0" >3831.292420</td>
#                         <td id="T_f2c40c88_dde9_11ea_b808_0242ac1c0002row7_col1" class="data row7 col1" >0.033053</td>
#             </tr>
#     </tbody></table>

# %%
data_ready
# Out:
#       short_code  Colorfulness_Picture  ...  Depth of field_value_Picture  likeCount
# 0          342.0                  34.0  ...                      0.213650      667.0
# 1          343.0                  42.0  ...                      0.378378     3297.0
# 2          346.0                  25.0  ...                      0.161826     4483.0
# 3          348.0                  57.0  ...                      0.276471     4187.0
# 4          350.0                  51.0  ...                      1.047619     4935.0
# ...          ...                   ...  ...                           ...        ...
# 1256       336.0                  34.0  ...                      0.081839        0.0
# 1257       337.0                  33.0  ...                      1.140461        0.0
# 1258       338.0                  15.0  ...                      2.698795        0.0
# 1259       339.0                  58.0  ...                      0.135385        0.0
# 1260       340.0                 130.0  ...                      1.178947        0.0
#
# [1261 rows x 20 columns]

# %%
x=data_ready[['Physical_Hor_Picture','ROT_Picture','Colorfulness_Picture','Color_balance_horizontal_Picture','Diagonal_dominance_Picture','Clarity_Picture']]

# %%
y = data_ready['likeCount']#your Y / dependent variable
x =x #your X/ Independent variabels
x = sm.add_constant(x)
model1= sm.OLS(y, x).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              likeCount   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     3.452
# Date:                Fri, 14 Aug 2020   Prob (F-statistic):            0.00219
# Time:                        05:01:13   Log-Likelihood:                -11970.
# No. Observations:                1261   AIC:                         2.395e+04
# Df Residuals:                    1254   BIC:                         2.399e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                             1712.1270   1750.617      0.978      0.328   -1722.334    5146.588
# Physical_Hor_Picture                 1.4558      1.939      0.751      0.453      -2.348       5.259
# ROT_Picture                         -0.5243      1.960     -0.268      0.789      -4.369       3.321
# Colorfulness_Picture                20.0494      4.929      4.067      0.000      10.379      29.720
# Color_balance_horizontal_Picture    -0.8933      2.719     -0.329      0.743      -6.227       4.440
# Diagonal_dominance_Picture          -4.8562      3.448     -1.409      0.159     -11.620       1.908
# Clarity_Picture                   1235.3117   1778.164      0.695      0.487   -2253.193    4723.817
# ==============================================================================
# Omnibus:                      177.649   Durbin-Watson:                   0.845
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              282.745
# Skew:                           0.945   Prob(JB):                     4.00e-62
# Kurtosis:                       4.344   Cond. No.                     4.99e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.99e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x=data_ready[[

# %%
y = data_ready['eng_score']#your Y / dependent variable
x =x #your X/ Independent variabels
x = sm.add_constant(x)
model3= sm.OLS(y, x).fit()

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              eng_score   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     6.403
# Date:                Fri, 14 Aug 2020   Prob (F-statistic):           4.30e-16
# Time:                        05:05:35   Log-Likelihood:                 953.35
# No. Observations:                1261   AIC:                            -1867.
# Df Residuals:                    1241   BIC:                            -1764.
# Df Model:                          19
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                -0.0899      0.071     -1.260      0.208      -0.230       0.050
# short_code                         7.334e-05   8.06e-06      9.098      0.000    5.75e-05    8.92e-05
# Colorfulness_Picture                  0.0005      0.000      1.898      0.058   -1.74e-05       0.001
# Saturation_Picture                   -0.0002      0.000     -1.647      0.100      -0.001    4.56e-05
# Contrast_Picture                     -0.0006      0.000     -1.187      0.235      -0.002       0.000
# Clarity_Picture                       0.1205      0.068      1.771      0.077      -0.013       0.254
# Brightness_Picture                   -0.0001      0.000     -1.058      0.290      -0.000       0.000
# Warm Hue_Picture                     -0.0030      0.013     -0.231      0.817      -0.029       0.023
# ROT_Picture                           0.0003   8.33e-05      3.156      0.002    9.94e-05       0.000
# Diagonal_dominance_Picture           -0.0002      0.000     -1.666      0.096      -0.000    3.74e-05
# Physical_ver_Picture                  0.0002   6.76e-05      3.514      0.000       0.000       0.000
# Physical_Hor_Picture                  0.0002   7.19e-05      3.101      0.002    8.19e-05       0.000
# Color_balance_vertical_Picture    -4.509e-05      0.000     -0.269      0.788      -0.000       0.000
# Color_balance_horizontal_Picture      0.0002      0.000      1.845      0.065   -1.54e-05       0.000
# Texture_difference_Picture            0.1247      0.076      1.636      0.102      -0.025       0.274
# Size_difference_Picture              -0.0247      0.019     -1.327      0.185      -0.061       0.012
# Color_difference_Picture           2.277e-05   8.25e-05      0.276      0.783      -0.000       0.000
# Depth of field_hue_Picture           -0.0001      0.000     -0.593      0.553      -0.000       0.000
# Depth of field_saturation_Picture -8.386e-05      0.000     -0.456      0.648      -0.000       0.000
# Depth of field_value_Picture         -0.0003      0.000     -0.762      0.446      -0.001       0.000
# ==============================================================================
# Omnibus:                      548.540   Durbin-Watson:                   1.164
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3258.012
# Skew:                           1.938   Prob(JB):                         0.00
# Kurtosis:                       9.855   Cond. No.                     2.97e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data_ready.head()
# Out:
#    short_code  Colorfulness_Picture  ...  Depth of field_value_Picture  likeCount
# 0       342.0                  34.0  ...                      0.213650      667.0
# 1       343.0                  42.0  ...                      0.378378     3297.0
# 2       346.0                  25.0  ...                      0.161826     4483.0
# 3       348.0                  57.0  ...                      0.276471     4187.0
# 4       350.0                  51.0  ...                      1.047619     4935.0
#
# [5 rows x 20 columns]

# %%
likes_data = pd.read_excel("Nespresso (1).xlsx").loc[:,["short_code","eng_score"]]

# %%
data_ready = visual_data.merge(likes_data, on="short_code", how="inner").fillna(0)

# %%
y = data_ready['eng_score']#your Y / dependent variable
x = data_ready.drop(['eng_score'], axis=1).astype(float) #your X/ Independent variabels
x = sm.add_constant(x)
model= sm.OLS(y, x).fit()

# %%
df_coeffs = pd.DataFrame({"Coefficients": model.params, "p": model.pvalues})
df_coeffs_sorted = df_coeffs.reindex(df_coeffs["p"].sort_values().index)
df_coeffs_sorted.style.bar(subset = ["Coefficients", "p"], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #5fba7d 41.9%, #5fba7d 41.9%, transparent 41.9%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.0%, transparent 0.0%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #5fba7d 41.9%, #5fba7d 42.0%, transparent 42.0%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.1%, transparent 0.1%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #5fba7d 41.9%, #5fba7d 42.0%, transparent 42.0%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.2%, transparent 0.2%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #5fba7d 41.9%, #5fba7d 42.0%, transparent 42.0%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.2%, transparent 0.2%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #5fba7d 41.9%, #5fba7d 42.1%, transparent 42.1%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 7.1%, transparent 7.1%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #5fba7d 41.9%, #5fba7d 42.0%, transparent 42.0%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 8.0%, transparent 8.0%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #5fba7d 41.9%, #5fba7d 98.1%, transparent 98.1%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 9.4%, transparent 9.4%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.8%, #d65f5f 41.8%, #d65f5f 41.9%, transparent 41.9%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.7%, transparent 11.7%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.8%, #d65f5f 41.8%, #d65f5f 41.9%, transparent 41.9%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 12.2%, transparent 12.2%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #5fba7d 41.9%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 12.5%, transparent 12.5%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.4%, #d65f5f 30.4%, #d65f5f 41.9%, transparent 41.9%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 22.6%, transparent 22.6%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.9%, transparent 41.9%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 25.4%, transparent 25.4%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.6%, #d65f5f 41.6%, #d65f5f 41.9%, transparent 41.9%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 28.8%, transparent 28.8%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.8%, #d65f5f 41.8%, #d65f5f 41.9%, transparent 41.9%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 35.5%, transparent 35.5%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.8%, #d65f5f 41.8%, #d65f5f 41.9%, transparent 41.9%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 54.6%, transparent 54.6%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.8%, #d65f5f 41.8%, #d65f5f 41.9%, transparent 41.9%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 67.7%, transparent 67.7%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #d65f5f 41.9%, #d65f5f 41.9%, transparent 41.9%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.3%, transparent 79.3%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #5fba7d 41.9%, #5fba7d 41.9%, transparent 41.9%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 95.8%, transparent 95.8%);
#         }    #T_04ff0eb4_ddec_11ea_b808_0242ac1c0002row18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, #d65f5f 41.9%, #d65f5f 41.9%, trans

# %%
df_coeffs = pd.DataFrame({"Coefficients": model.params[model.pvalues<0.05], "p": model.pvalues[model.pvalues<0.05]})
df_coeffs_sorted = df_coeffs.reindex(df_coeffs["p"].sort_values().index)
df_coeffs_sorted.style.bar(subset = ["Coefficients", "p"], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 27.9%, transparent 27.9%);
#         }    #T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.0%, transparent 0.0%);
#         }    #T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 90.4%, transparent 90.4%);
#         }    #T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 23.2%, transparent 23.2%);
#         }    #T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.1%, transparent 83.1%);
#         }    #T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 84.8%, transparent 84.8%);
#         }    #T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }</style><table id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coefficients</th>        <th class="col_heading level0 col1" >p</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002level0_row0" class="row_heading level0 row0" >short_code</th>
#                         <td id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row0_col0" class="data row0 col0" >0.000073</td>
#                         <td id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row0_col1" class="data row0 col1" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002level0_row1" class="row_heading level0 row1" >Physical_ver_Picture</th>
#                         <td id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row1_col0" class="data row1 col0" >0.000237</td>
#                         <td id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row1_col1" class="data row1 col1" >0.000457</td>
#             </tr>
#             <tr>
#                         <th id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002level0_row2" class="row_heading level0 row2" >ROT_Picture</th>
#                         <td id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row2_col0" class="data row2 col0" >0.000263</td>
#                         <td id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row2_col1" class="data row2 col1" >0.001639</td>
#             </tr>
#             <tr>
#                         <th id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002level0_row3" class="row_heading level0 row3" >Physical_Hor_Picture</th>
#                         <td id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row3_col0" class="data row3 col0" >0.000223</td>
#                         <td id="T_5b2a7b94_ddeb_11ea_b808_0242ac1c0002row3_col1" class="data row3 col1" >0.001972</td>
#             </tr>
#     </tbody></table>

# %%
likes_data = pd.read_excel("Nespresso (1).xlsx").loc[:,["short_code","contains_coffee"]]

# %%
data_ready = visual_data.merge(likes_data, on="short_code", how="inner").fillna(0)

# %%
y = data_ready['contains_coffee']#your Y / dependent variable
x = data_ready.drop(['contains_coffee'], axis=1).astype(float) #your X/ Independent variabels
x = sm.add_constant(x)
model= sm.OLS(y, x).fit()

# %%
df_coeffs = pd.DataFrame({"Coefficients": model.params, "p": model.pvalues})
df_coeffs_sorted = df_coeffs.reindex(df_coeffs["p"].sort_values().index)
df_coeffs_sorted.style.bar(subset = ["Coefficients", "p"], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #5fba7d 44.7%, #5fba7d 44.7%, transparent 44.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.0%, transparent 0.0%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.6%, #d65f5f 44.6%, #d65f5f 44.7%, transparent 44.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 3.5%, transparent 3.5%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.6%, #d65f5f 44.6%, #d65f5f 44.7%, transparent 44.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 4.5%, transparent 4.5%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #5fba7d 44.7%, #5fba7d 44.9%, transparent 44.9%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 5.1%, transparent 5.1%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #5fba7d 44.7%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 5.9%, transparent 5.9%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #5fba7d 44.7%, #5fba7d 44.8%, transparent 44.8%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 6.2%, transparent 6.2%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.6%, #d65f5f 44.6%, #d65f5f 44.7%, transparent 44.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 8.7%, transparent 8.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #5fba7d 44.7%, #5fba7d 44.8%, transparent 44.8%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 12.6%, transparent 12.6%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #5fba7d 44.7%, #5fba7d 44.7%, transparent 44.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 13.7%, transparent 13.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 44.7%, transparent 44.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 14.8%, transparent 14.8%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #5fba7d 44.7%, #5fba7d 44.9%, transparent 44.9%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 23.7%, transparent 23.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #5fba7d 44.7%, #5fba7d 79.6%, transparent 79.6%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 29.8%, transparent 29.8%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #5fba7d 44.7%, #5fba7d 50.6%, transparent 50.6%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 30.3%, transparent 30.3%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.6%, #d65f5f 44.6%, #d65f5f 44.7%, transparent 44.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 53.5%, transparent 53.5%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #d65f5f 44.7%, #d65f5f 44.7%, transparent 44.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 58.1%, transparent 58.1%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #5fba7d 44.7%, #5fba7d 44.8%, transparent 44.8%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 63.3%, transparent 63.3%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.6%, #d65f5f 42.6%, #d65f5f 44.7%, transparent 44.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.6%, transparent 83.6%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #d65f5f 44.7%, #d65f5f 44.7%, transparent 44.7%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.1%, transparent 86.1%);
#         }    #T_0e7ebf02_d9ff_11ea_9e1b_0242ac1c0002row18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #d65f5f 44.7%, #d65f5f 44.7%, trans
